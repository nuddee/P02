# %% [markdown]
# <a href="https://colab.research.google.com/github/nuddee/P02/blob/main/P02_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/DRD.zip /content/

# %%
# !unzip DRD.zip
# Out:
# Archive:  DRD.zip
#    creating: content/-DRD/
#    creating: content/-DRD/train_images/
#   inflating: content/-DRD/train_images/Mild_DR_79.png
#   inflating: content/-DRD/train_images/cb602182cde3.png
#   inflating: content/-DRD/train_images/1638404f385c.png
#   inflating: content/-DRD/train_images/Healthy_460.png
#   inflating: content/-DRD/train_images/Mild_DR_164.png
#   inflating: content/-DRD/train_images/21d18b022429.png
#   inflating: content/-DRD/train_images/Mild_DR_168.png
#   inflating: content/-DRD/train_images/Moderate_DR_273.png
#   inflating: content/-DRD/train_images/5c817060c0ed.png
#   inflating: content/-DRD/train_images/20f86e068276.png
#   inflating: content/-DRD/train_images/272d9c043c81.png
#   inflating: content/-DRD/train_images/61c2fbd16e38.png
#   inflating: content/-DRD/train_images/Healthy_568.png
#   inflating: content/-DRD/train_images/6966abf40b8c.png
#   inflating: content/-DRD/train_images/Healthy_438.png
#   inflating: content/-DRD/train_images/Healthy_298.png
#   inflating: content/-DRD/train_images/Proliferate DR_92.png
#   inflating: content/-DRD/train_images/91b6ebaa3678.png
#   inflating: content/-DRD/train_images/Healthy_981.png
#   inflating: content/-DRD/train_images/461fa5292fda.png
#   inflating: content/-DRD/train_images/ea9e0fb6fb0b.png
#   inflating: content/-DRD/train_images/60edda7b4871.png
#   inflating: content/-DRD/train_images/d865997a6280.png
#   inflating: content/-DRD/train_images/Moderate_DR_73.png
#   inflating: content/-DRD/train_images/07a2b8cabf6b.png
#   inflating: content/-DRD/train_images/Healthy_803.png
#   inflating: content/-DRD/train_images/6253f23229b1.png
#   inflating: content/-DRD/train_images/6889bc64ab09.png
#   inflating: content/-DRD/train_images/7831ce1d895e.png
#   inflating: content/-DRD/train_images/1fd5d860d4d7.png
#   inflating: content/-DRD/train_images/ca360bec5851.png
#   inflating: content/-DRD/train_images/b9d0b83d70c3.png
#   inflating: content/-DRD/train_images/bda7ff3b1562.png
#   inflating: content/-DRD/train_images/Mild_DR_80.png
#   inflating: content/-DRD/train_images/Moderate_DR_445.png
#   inflating: content/-DRD/train_images/01c7808d901d.png
#   inflating: content/-DRD/train_images/Moderate_DR_182.png
#   inflating: content/-DRD/train_images/Proliferate DR_151.png
#   inflating: content/-DRD/train_images/Moderate_DR_407.png
#   inflating: content/-DRD/train_images/Moderate_DR_231.png
#   inflating: content/-DRD/train_images/Severe DR_170.png
#   inflating: content/-DRD/train_images/e663c6627a95.png
#   inflating: content/-DRD/train_images/Moderate_DR_572.png
#   inflating: content/-DRD/train_images/Healthy_220.png
#   inflating: content/-DRD/train_images/Proliferate DR_203.png
#   inflating: content/-DRD/train_images/Moderate_DR_882.png
#   inflating: content/-DRD/train_images/Moderate_DR_41.png
#   inflating: content/-DRD/train_images/Healthy_597.png
#   inflating: content/-DRD/train_images/a8854768549f.png
#   inflating: content/-DRD/train_images/Healthy_327.png
#   inflating: content/-DRD/train_images/Moderate_DR_430.png
#   inflating: content/-DRD/train_images/65c958379680.png
#   inflating: content/-DRD/train_images/2700754f71e9.png
#   inflating: content/-DRD/train_images/Healthy_348.png
#   inflating: content/-DRD/train_images/Severe DR_3.png
#   inflating: content/-DRD/train_images/Moderate_DR_472.png
#   inflating: content/-DRD/train_images/75ed83dbccce.png
#   inflating: content/-DRD/train_images/e4d3d437b0a8.png
#   inflating: content/-DRD/train_images/Mild_DR_325.png
#   inflating: content/-DRD/train_images/e4dcca36ceb4.png
#   inflating: content/-DRD/train_images/Moderate_DR_721.png
#   inflating: content/-DRD/train_images/8a81f62320d6.png
#   inflating: content/-DRD/train_images/f69400b316a7.png
#   inflating: content/-DRD/train_images/Moderate_DR_549.png
#   inflating: content/-DRD/train_images/6e73acb2cf60.png
#   inflating: content/-DRD/train_images/Healthy_992.png
#   inflating: content/-DRD/train_images/Moderate_DR_332.png
#   inflating: content/-DRD/train_images/Moderate_DR_4.png
#   inflating: content/-DRD/train_images/f64214bed40e.png
#   inflating: content/-DRD/train_images/Moderate_DR_698.png
#   inflating: content/-DRD/train_images/726dff37edc0.png
#   inflating: content/-DRD/train_images/a804cef3e51f.png
#   inflating: content/-DRD/train_images/c639d837f5e4.png
#   inflating: content/-DRD/train_images/66460ecab347.png
#   inflating: content/-DRD/train_images/Healthy_246.png
#   inflating: content/-DRD/train_images/44271f3cb18f.png
#   inflating: content/-DRD/train_images/8906c9ed54a2.png
#   inflating: content/-DRD/train_images/e2161692a0b4.png
#   inflating: content/-DRD/train_images/2ecbc2e3f239.png
#   inflating: content/-DRD/train_images/8185ce1cdcef.png
#   inflating: content/-DRD/train_images/Healthy_268.png
#   inflating: content/-DRD/train_images/Proliferate DR_53.png
#   inflating: content/-DRD/train_images/896ad584a841.png
#   inflating: content/-DRD/train_images/Healthy_684.png
#   inflating: content/-DRD/train_images/1e4b3b823b95.png
#   inflating: content/-DRD/train_images/Healthy_781.png
#   inflating: content/-DRD/train_images/Healthy_987.png
#   inflating: content/-DRD/train_images/150fc7127582.png
#   inflating: content/-DRD/train_images/d807c53c1399.png
#   inflating: content/-DRD/train_images/1da4a17c18c9.png
#   inflating: content/-DRD/train_images/c365c598ad4e.png
#   inflating: content/-DRD/train_images/3599029efeb3.png
#   inflating: content/-DRD/train_images/Proliferate DR_189.png
#   inflating: content/-DRD/train_images/Healthy_690.png
#   inflating: content/-DRD/train_images/33d72035c27a.png
#   inflating: content/-DRD/train_images/75a7bc945b7d.png
#   inflating: content/-DRD/train_images/467b7d9d811c.png
#   inflating: content/-DRD/train_images/Healthy_737.png
#   inflating: content/-DRD/train_images/Mild_DR_5.png
#   inflating: content/-DRD/train_images/7347f5133a6a.png
#   inflating: content/-DRD/train_images/cc9270f06b65.png
#   inflating: content/-DRD/train_images/Healthy_240.png
#   inflating: content/-DRD/train_images/Healthy_241.png
#   inflating: content/-DRD/train_images/62318d514160.png
#   inflating: content/-DRD/train_images/69df7ade0575.png
#   inflating: content/-DRD/train_images/6d259b5b4c76.png
#   inflating: content/-DRD/train_images/Moderate_DR_731.png
#   inflating: content/-DRD/train_images/71f6a6e4620a.png
#   inflating: content/-DRD/train_images/4da2961e62fe.png
#   inflating: content/-DRD/train_images/Proliferate DR_208.png
#   inflating: content/-DRD/train_images/68ddb15a74de.png
#   inflating: content/-DRD/train_images/Moderate_DR_607.png
#   inflating: content/-DRD/train_images/2b88cb6e31cd.png
#   inflating: content/-DRD/train_images/Healthy_293.png
#   inflating: content/-DRD/train_images/Healthy_524.png
#   inflating: content/-DRD/train_images/2c2aa057afc5.png
#   inflating: content/-DRD/train_images/39aa3cd93c50.png
#   inflating: content/-DRD/train_images/Healthy_117.png
#   inflating: content/-DRD/train_images/Healthy_946.png
#   inflating: content/-DRD/train_images/Mild_DR_138.png
#   inflating: content/-DRD/train_images/ecad6845f630.png
#   inflating: content/-DRD/train_images/Healthy_4.png
#   inflating: content/-DRD/train_images/b5a3ca5c0a80.png
#   inflating: content/-DRD/train_images/80a02014b418.png
#   inflating: content/-DRD/train_images/Severe DR_168.png
#   inflating: content/-DRD/train_images/9bd008aab548.png
#   inflating: content/-DRD/train_images/Moderate_DR_515.png
#   inflating: content/-DRD/train_images/Moderate_DR_133.png
#   inflating: content/-DRD/train_images/83e529e95b0e.png
#   inflating: content/-DRD/train_images/c252da9b41d8.png
#   inflating: content/-DRD/train_images/Proliferate DR_174.png
#   inflating: content/-DRD/train_images/5b1c4cefeb24.png
#   inflating: content/-DRD/train_images/Moderate_DR_206.png
#   inflating: content/-DRD/train_images/92889b863ae6.png
#   inflating: content/-DRD/train_images/c406325360b1.png
#   inflating: content/-DRD/train_images/Moderate_DR_155.png
#   inflating: content/-DRD/train_images/Healthy_218.png
#   inflating: content/-DRD/train_images/Healthy_28.png
#   inflating: content/-DRD/train_images/Moderate_DR_863.png
#   inflating: content/-DRD/train_images/Proliferate DR_107.png
#   inflating: content/-DRD/train_images/Moderate_DR_153.png
#   inflating: content/-DRD/train_images/ea5c42a78979.png
#   inflating: content/-DRD/train_images/57f5ad4b5b29.png
#   inflating: content/-DRD/train_images/Healthy_68.png
#   inflating: content/-DRD/train_images/Moderate_DR_764.png
#   inflating: content/-DRD/train_images/7b20210d9120.png
#   inflating: content/-DRD/train_images/Severe DR_24.png
#   inflating: content/-DRD/train_images/Moderate_DR_293.png
#   inflating: content/-DRD/train_images/f62b8a076833.png
#   inflating: content/-DRD/train_images/Healthy_529.png
#   inflating: content/-DRD/train_images/Proliferate DR_187.png
#   inflating: content/-DRD/train_images/Moderate_DR_542.png
#   inflating: content/-DRD/train_images/Healthy_184.png
#   inflating: content/-DRD/train_images/Healthy_45.png
#   inflating: content/-DRD/train_images/29f44aea93a4.png
#   inflating: content/-DRD/train_images/Healthy_724.png
#   inflating: content/-DRD/train_images/c7d0deb71576.png
#   inflating: content/-DRD/train_images/Healthy_587.png
#   inflating: content/-DRD/train_images/Healthy_716.png
#   inflating: content/-DRD/train_images/Severe DR_19.png
#   inflating: content/-DRD/train_images/Mild_DR_145.png
#   inflating: content/-DRD/train_images/Proliferate DR_279.png
#   inflating: content/-DRD/train_images/Moderate_DR_673.png
#   inflating: content/-DRD/train_images/Moderate_DR_544.png
#   inflating: content/-DRD/train_images/6cfb7b44ef6f.png
#   inflating: content/-DRD/train_images/0c55d58bebaf.png
#   inflating: content/-DRD/train_images/962cf85e4f6d.png
#   inflating: content/-DRD/train_images/5ac7a414560e.png
#   inflating: content/-DRD/train_images/880edb2cdb69.png
#   inflating: content/-DRD/train_images/Proliferate DR_75.png
#   inflating: content/-DRD/train_images/830e297965a1.png
#   inflating: content/-DRD/train_images/Mild_DR_230.png
#   inflating: content/-DRD/train_images/8421107255ae.png
#   inflating: content/-DRD/train_images/c334f8688b77.png
#   inflating: content/-DRD/train_images/Moderate_DR_13.png
#   inflating: content/-DRD/train_images/76bc31e0d3be.png
#   inflating: content/-DRD/train_images/99ecdb41d5e7.png
#   inflating: content/-DRD/train_images/Proliferate DR_281.png
#   inflating: content/-DRD/train_images/bfd5c0e55420.png
#   inflating: content/-DRD/train_images/Moderate_DR_900.png
#   inflating: content/-DRD/train_images/e4e343eaae2a.png
#   inflating: content/-DRD/train_images/f56ff0440ed1.png
#   inflating: content/-DRD/train_images/Healthy_955.png
#   inflating: content/-DRD/train_images/Proliferate DR_251.png
#   inflating: content/-DRD/train_images/Mild_DR_358.png
#   inflating: content/-DRD/train_images/Healthy_646.png
#   inflating: content/-DRD/train_images/Healthy_205.png
#   inflating: content/-DRD/train_images/af8aa32beee4.png
#   inflating: content/-DRD/train_images/2f284b6a1940.png
#   inflating: content/-DRD/train_images/Healthy_521.png
#   inflating: content/-DRD/train_images/72c31aa48e2c.png
#   inflating: content/-DRD/train_images/Proliferate DR_221.png
#   inflating: content/-DRD/train_images/e246cd89e1cc.png
#   inflating: content/-DRD/train_images/144a1a426137.png
#   inflating: content/-DRD/train_images/Healthy_723.png
#   inflating: content/-DRD/train_images/Moderate_DR_113.png
#   inflating: content/-DRD/train_images/Healthy_273.png
#   inflating: content/-DRD/train_images/Healthy_854.png
#   inflating: content/-DRD/train_images/9f935fb38440.png
#   inflating: content/-DRD/train_images/Moderate_DR_81.png
#   inflating: content/-DRD/train_images/6c4ec95dd8ba.png
#   inflating: content/-DRD/train_images/67844c46bc61.png
#   inflating: content/-DRD/train_images/Moderate_DR_127.png
#   inflating: content/-DRD/train_images/fc603cbedb41.png
#   inflating: content/-DRD/train_images/Severe DR_57.png
#   inflating: content/-DRD/train_images/6c6505a0c637.png
#   inflating: content/-DRD/train_images/Proliferate DR_50.png
#   inflating: content/-DRD/train_images/263d8851e33b.png
#   inflating: content/-DRD/train_images/fce73678f650.png
#   inflating: content/-DRD/train_images/fc4d69128e7c.png
#   inflating: content/-DRD/train_images/Moderate_DR_410.png
#   inflating: content/-DRD/train_images/c0a0828e01b4.png
#   inflating: content/-DRD/train_images/15b21c80cc31.png
#   inflating: content/-DRD/train_images/85cc6d636898.png
#   inflating: content/-DRD/train_images/3178559fbf57.png
#   inflating: content/-DRD/train_images/Proliferate DR_181.png
#   inflating: content/-DRD/train_images/Healthy_880.png
#   inflating: content/-DRD/train_images/85fce24084da.png
#   inflating: content/-DRD/train_images/f298b7d05958.png
#   inflating: content/-DRD/train_images/Healthy_609.png
#   inflating: content/-DRD/train_images/f4e68b61f480.png
#   inflating: content/-DRD/train_images/c446985355f1.png
#   inflating: content/-DRD/train_images/Mild_DR_109.png
#   inflating: content/-DRD/train_images/a3fcf42ff56d.png
#   inflating: content/-DRD/train_images/eabf421f94d0.png
#   inflating: content/-DRD/train_images/5e52c9fe676f.png
#   inflating: content/-DRD/train_images/e265c870f9b3.png
#   inflating: content/-DRD/train_images/Healthy_784.png
#   inflating: content/-DRD/train_images/101b9ebfc720.png
#   inflating: content/-DRD/train_images/a9bc2f892cb3.png
#   inflating: content/-DRD/train_images/Proliferate DR_55.png
#   inflating: content/-DRD/train_images/582115961a3d.png
#   inflating: content/-DRD/train_images/Moderate_DR_511.png
#   inflating: content/-DRD/train_images/05a5183c92d0.png
#   inflating: content/-DRD/train_images/a528be013a04.png
#   inflating: content/-DRD/train_images/Moderate_DR_368.png
#   inflating: content/-DRD/train_images/f994a3b07935.png
#   inflating: content/-DRD/train_images/e8d1c6c07cf2.png
#   inflating: content/-DRD/train_images/af6166d57f13.png
#   inflating: content/-DRD/train_images/7d3835e4e63a.png
#   inflating: content/-DRD/train_images/cd29c88c9e36.png
#   inflating: content/-DRD/train_images/Moderate_DR_468.png
#   inflating: content/-DRD/train_images/6fb656d506b2.png
#   inflating: content/-DRD/train_images/437cbec4a3f8.png
#   inflating: content/-DRD/train_images/d3d578fe433f.png
#   inflating: content/-DRD/train_images/Healthy_420.png
#   inflating: content/-DRD/train_images/913b1890ed1e.png
#   inflating: content/-DRD/train_images/050bb1eafa76.png
#   inflating: content/-DRD/train_images/fcc32dffd24d.png
#   inflating: content/-DRD/train_images/Healthy_182.png
#   inflating: content/-DRD/train_images/Moderate_DR_49.png
#   inflating: content/-DRD/train_images/Severe DR_67.png
#   inflating: content/-DRD/train_images/Healthy_556.png
#   inflating: content/-DRD/train_images/Moderate_DR_777.png
#   inflating: content/-DRD/train_images/1177d583c807.png
#   inflating: content/-DRD/train_images/Moderate_DR_826.png
#   inflating: content/-DRD/train_images/384db24ebbd7.png
#   inflating: content/-DRD/train_images/Moderate_DR_853.png
#   inflating: content/-DRD/train_images/Healthy_135.png
#   inflating: content/-DRD/train_images/b22cc1bf0b8a.png
#   inflating: content/-DRD/train_images/b13d72ceea26.png
#   inflating: content/-DRD/train_images/Moderate_DR_6.png
#   inflating: content/-DRD/train_images/ea15a290eb96.png
#   inflating: content/-DRD/train_images/7c90ab025331.png
#   inflating: content/-DRD/train_images/e62490b7d0e9.png
#   inflating: content/-DRD/train_images/a8b3c0961d42.png
#   inflating: content/-DRD/train_images/Healthy_79.png
#   inflating: content/-DRD/train_images/Moderate_DR_74.png
#   inflating: content/-DRD/train_images/a2ad3da4c7d6.png
#   inflating: content/-DRD/train_images/Healthy_119.png
#   inflating: content/-DRD/train_images/6cbc3dad809c.png
#   inflating: content/-DRD/train_images/Moderate_DR_678.png
#   inflating: content/-DRD/train_images/Healthy_637.png
#   inflating: content/-DRD/train_images/8fd7ad26e691.png
#   inflating: content/-DRD/train_images/2e79041ef722.png
#   inflating: content/-DRD/train_images/500aad15b7c8.png
#   inflating: content/-DRD/train_images/Healthy_752.png
#   inflating: content/-DRD/train_images/Mild_DR_15.png
#   inflating: content/-DRD/train_images/a95858e052d6.png
#   inflating: content/-DRD/train_images/Moderate_DR_160.png
#   inflating: content/-DRD/train_images/00cc2b75cddd.png
#   inflating: content/-DRD/train_images/42af7282349b.png
#   inflating: content/-DRD/train_images/Healthy_905.png
#   inflating: content/-DRD/train_images/Healthy_544.png
#   inflating: content/-DRD/train_images/5b3d41626ec5.png
#   inflating: content/-DRD/train_images/Healthy_421.png
#   inflating: content/-DRD/train_images/5188a8afa879.png
#   inflating: content/-DRD/train_images/f7e9fa75c7c1.png
#   inflating: content/-DRD/train_images/6061f5b7378d.png
#   inflating: content/-DRD/train_images/e97ecf4355cb.png
#   inflating: content/-DRD/train_images/79cbae28d8b2.png
#   inflating: content/-DRD/train_images/4318b6adeb97.png
#   inflating: content/-DRD/train_images/cd54d022e37d.png
#   inflating: content/-DRD/train_images/82088c6734e6.png
#   inflating: content/-DRD/train_images/Moderate_DR_290.png
#   inflating: content/-DRD/train_images/Moderate_DR_791.png
#   inflating: content/-DRD/train_images/Healthy_122.png
#   inflating: content/-DRD/train_images/e1dc02a3dc2a.png
#   inflating: content/-DRD/train_images/Proliferate DR_199.png
#   inflating: content/-DRD/train_images/Healthy_865.png
#   inflating: content/-DRD/train_images/4d1cf360b2d7.png
#   inflating: content/-DRD/train_images/Moderate_DR_386.png
#   inflating: content/-DRD/train_images/Healthy_975.png
#   inflating: content/-DRD/train_images/f080a22008be.png
#   inflating: content/-DRD/train_images/Moderate_DR_780.png
#   inflating: content/-DRD/train_images/Healthy_773.png
#   inflating: content/-DRD/train_images/Proliferate DR_277.png
#   inflating: content/-DRD/train_images/Healthy_930.png
#   inflating: content/-DRD/train_images/Moderate_DR_202.png
#   inflating: content/-DRD/train_images/4faf4063db8c.png
#   inflating: content/-DRD/train_images/Mild_DR_240.png
#   inflating: content/-DRD/train_images/Mild_DR_253.png
#   inflating: content/-DRD/train_images/Moderate_DR_539.png
#   inflating: content/-DRD/train_images/89b044cbaf85.png
#   inflating: content/-DRD/train_images/Moderate_DR_45.png
#   inflating: content/-DRD/train_images/Healthy_900.png
#   inflating: content/-DRD/train_images/Moderate_DR_688.png
#   inflating: content/-DRD/train_images/Proliferate DR_41.png
#   inflating: content/-DRD/train_images/Moderate_DR_239.png
#   inflating: content/-DRD/train_images/269f0792f11f.png
#   inflating: content/-DRD/train_images/Healthy_373.png
#   inflating: content/-DRD/train_images/Mild_DR_286.png
#   inflating: content/-DRD/train_images/175dd560810a.png
#   inflating: content/-DRD/train_images/a45d77edf8d9.png
#   inflating: content/-DRD/train_images/Healthy_288.png
#   inflating: content/-DRD/train_images/4489d421e5aa.png
#   inflating: content/-DRD/train_images/Healthy_486.png
#   inflating: content/-DRD/train_images/Proliferate DR_214.png
#   inflating: content/-DRD/train_images/c7b622ec8104.png
#   inflating: content/-DRD/train_images/f999c6921e6d.png
#   inflating: content/-DRD/train_images/Moderate_DR_691.png
#   inflating: content/-DRD/train_images/Moderate_DR_690.png
#   inflating: content/-DRD/train_images/Moderate_DR_340.png
#   inflating: content/-DRD/train_images/Healthy_850.png
#   inflating: content/-DRD/train_images/5b3e7197ac1c.png
#   inflating: content/-DRD/train_images/Severe DR_125.png
#   inflating: content/-DRD/train_images/4958bfcc9f38.png
#   inflating: content/-DRD/train_images/bb08949dd70a.png
#   inflating: content/-DRD/train_images/e9678824215d.png
#   inflating: content/-DRD/train_images/Healthy_176.png
#   inflating: content/-DRD/train_images/Severe DR_130.png
#   inflating: content/-DRD/train_images/57ce57a8cfb0.png
#   inflating: content/-DRD/train_images/Moderate_DR_864.png
#   inflating: content/-DRD/train_images/Healthy_405.png
#   inflating: content/-DRD/train_images/Moderate_DR_591.png
#   inflating: content/-DRD/train_images/Healthy_162.png
#   inflating: content/-DRD/train_images/a654b25124c3.png
#   inflating: content/-DRD/train_images/568455854a11.png
#   inflating: content/-DRD/train_images/436e7a7af761.png
#   inflating: content/-DRD/train_images/a0b7ad98df57.png
#   inflating: content/-DRD/train_images/1541226c5d72.png
#   inflating: content/-DRD/train_images/f0a2dc580009.png
#   inflating: content/-DRD/train_images/Healthy_242.png
#   inflating: content/-DRD/train_images/Moderate_DR_339.png
#   inflating: content/-DRD/train_images/0eced86c9db8.png
#   inflating: content/-DRD/train_images/537e50fdf22e.png
#   inflating: content/-DRD/train_images/1e1fb019710d.png
#   inflating: content/-DRD/train_images/ab32db41c409.png
#   inflating: content/-DRD/train_images/ea05c22d92e9.png
#   inflating: content/-DRD/train_images/60eeae3ba23d.png
#   inflating: content/-DRD/train_images/Healthy_349.png
#   inflating: content/-DRD/train_images/93802d1e3c41.png
#   inflating: content/-DRD/train_images/Moderate_DR_77.png
#   inflating: content/-DRD/train_images/Proliferate DR_168.png
#   inflating: content/-DRD/train_images/Healthy_855.png
#   inflating: content/-DRD/train_images/e03a74e7d74f.png
#   inflating: content/-DRD/train_images/Moderate_DR_600.png
#   inflating: content/-DRD/train_images/Healthy_943.png
#   inflating: content/-DRD/train_images/Moderate_DR_843.png
#   inflating: content/-DRD/train_images/Proliferate DR_243.png
#   inflating: content/-DRD/train_images/d6df4fe492ec.png
#   inflating: content/-DRD/train_images/4e4a6224a04e.png
#   inflating: content/-DRD/train_images/0ada12c0e78f.png
#   inflating: content/-DRD/train_images/Severe DR_84.png
#   inflating: content/-DRD/train_images/Healthy_202.png
#   inflating: content/-DRD/train_images/393fa5a023a5.png
#   inflating: content/-DRD/train_images/810d3779abd9.png
#   inflating: content/-DRD/train_images/76516f828d88.png
#   inflating: content/-DRD/train_images/Moderate_DR_701.png
#   inflating: content/-DRD/train_images/Mild_DR_58.png
#   inflating: content/-DRD/train_images/ef8c39eb9157.png
#   inflating: content/-DRD/train_images/Mild_DR_287.png
#   inflating: content/-DRD/train_images/aafb0c944f14.png
#   inflating: content/-DRD/train_images/Healthy_689.png
#   inflating: content/-DRD/train_images/Healthy_416.png
#   inflating: content/-DRD/train_images/80dbeb0fdc75.png
#   inflating: content/-DRD/train_images/Moderate_DR_59.png
#   inflating: content/-DRD/train_images/51d574513bcb.png
#   inflating: content/-DRD/train_images/c597ef460944.png
#   inflating: content/-DRD/train_images/Healthy_914.png
#   inflating: content/-DRD/train_images/5f13e8a07344.png
#   inflating: content/-DRD/train_images/42b9c1977681.png
#   inflating: content/-DRD/train_images/a384e688e228.png
#   inflating: content/-DRD/train_images/07a0e34c8d20.png
#   inflating: content/-DRD/train_images/f7defe70afc3.png
#   inflating: content/-DRD/train_images/917f76f360b6.png
#   inflating: content/-DRD/train_images/c5b58cc992af.png
#   inflating: content/-DRD/train_images/c096131ad065.png
#   inflating: content/-DRD/train_images/2a3a1ed1c285.png
#   inflating: content/-DRD/train_images/98441214557f.png
#   inflating: content/-DRD/train_images/e5d56f4f359b.png
#   inflating: content/-DRD/train_images/ab88081e5654.png
#   inflating: content/-DRD/train_images/62b4be2799ca.png
#   inflating: content/-DRD/train_images/a34fc5376669.png
#   inflating: content/-DRD/train_images/cd9e2190c73f.png
#   inflating: content/-DRD/train_images/Moderate_DR_801.png
#   inflating: content/-DRD/train_images/0b64a0a06f9a.png
#   inflating: content/-DRD/train_images/80feb1f7ca5e.png
#   inflating: content/-DRD/train_images/Moderate_DR_889.png
#   inflating: content/-DRD/train_images/42cc993f23a9.png
#   inflating: content/-DRD/train_images/Moderate_DR_560.png
#   inflating: content/-DRD/train_images/Severe DR_147.png
#   inflating: content/-DRD/train_images/Healthy_500.png
#   inflating: content/-DRD/train_images/Healthy_52.png
#   inflating: content/-DRD/train_images/Healthy_67.png
#   inflating: content/-DRD/train_images/Moderate_DR_335.png
#   inflating: content/-DRD/train_images/c8905b8d5cf1.png
#   inflating: content/-DRD/train_images/Moderate_DR_898.png
#   inflating: content/-DRD/train_images/b10fca20c885.png
#   inflating: content/-DRD/train_images/807135cbc438.png
#   inflating: content/-DRD/train_images/Moderate_DR_7.png
#   inflating: content/-DRD/train_images/Healthy_927.png
#   inflating: content/-DRD/train_images/c2d2b4f536da.png
#   inflating: content/-DRD/train_images/79be2ff796bf.png
#   inflating: content/-DRD/train_images/Proliferate DR_180.png
#   inflating: content/-DRD/train_images/665ce639a331.png
#   inflating: content/-DRD/train_images/Moderate_DR_618.png
#   inflating: content/-DRD/train_images/b842b43cb7fb.png
#   inflating: content/-DRD/train_images/Severe DR_182.png
#   inflating: content/-DRD/train_images/Mild_DR_222.png
#   inflating: content/-DRD/train_images/35cd9832fc0a.png
#   inflating: content/-DRD/train_images/d0926ed2c8e5.png
#   inflating: content/-DRD/train_images/Moderate_DR_271.png
#   inflating: content/-DRD/train_images/Moderate_DR_720.png
#   inflating: content/-DRD/train_images/Moderate_DR_799.png
#   inflating: content/-DRD/train_images/Healthy_815.png
#   inflating: content/-DRD/train_images/Mild_DR_312.png
#    creating: content/-DRD/train_images/.ipynb_checkpoints/
#   inflating: content/-DRD/train_images/f45f1485c940.png
#   inflating: content/-DRD/train_images/Mild_DR_71.png
#   inflating: content/-DRD/train_images/Moderate_DR_338.png
#   inflating: content/-DRD/train_images/Moderate_DR_125.png
#   inflating: content/-DRD/train_images/bed8296c8dfe.png
#   inflating: content/-DRD/train_images/Moderate_DR_493.png
#   inflating: content/-DRD/train_images/d9ba044671e1.png
#   inflating: content/-DRD/train_images/07929d32b5b3.png
#   inflating: content/-DRD/train_images/Proliferate DR_216.png
#   inflating: content/-DRD/train_images/Healthy_315.png
#   inflating: content/-DRD/train_images/d99dd99be001.png
#   inflating: content/-DRD/train_images/f8f5942b690e.png
#   inflating: content/-DRD/train_images/12e3f5f2cb17.png
#   inflating: content/-DRD/train_images/Mild_DR_112.png
#   inflating: content/-DRD/train_images/6b07971c3bf6.png
#   inflating: content/-DRD/train_images/Proliferate DR_207.png
#   inflating: content/-DRD/train_images/Moderate_DR_461.png
#   inflating: content/-DRD/train_images/Moderate_DR_189.png
#   inflating: content/-DRD/train_images/81bc03e2ff2b.png
#   inflating: content/-DRD/train_images/d3e56584a481.png
#   inflating: content/-DRD/train_images/904b03ad5594.png
#   inflating: content/-DRD/train_images/73e83a07a16d.png
#   inflating: content/-DRD/train_images/Moderate_DR_640.png
#   inflating: content/-DRD/train_images/Moderate_DR_404.png
#   inflating: content/-DRD/train_images/1864d3411143.png
#   inflating: content/-DRD/train_images/Healthy_434.png
#   inflating: content/-DRD/train_images/Mild_DR_364.png
#   inflating: content/-DRD/train_images/Moderate_DR_276.png
#   inflating: content/-DRD/train_images/Proliferate DR_245.png
#   inflating: content/-DRD/train_images/Mild_DR_104.png
#   inflating: content/-DRD/train_images/Proliferate DR_148.png
#   inflating: content/-DRD/train_images/166068a24416.png
#   inflating: content/-DRD/train_images/a125377fb985.png
#   inflating: content/-DRD/train_images/Moderate_DR_526.png
#   inflating: content/-DRD/train_images/1cb814ed6332.png
#   inflating: content/-DRD/train_images/Healthy_283.png
#   inflating: content/-DRD/train_images/6531070bf03c.png
#   inflating: content/-DRD/train_images/Moderate_DR_834.png
#   inflating: content/-DRD/train_images/dd02d60bef14.png
#   inflating: content/-DRD/train_images/bfdee9be1f1d.png
#   inflating: content/-DRD/train_images/941d874c8afb.png
#   inflating: content/-DRD/train_images/8be6629a6039.png
#   inflating: content/-DRD/train_images/30db694bee42.png
#   inflating: content/-DRD/train_images/Moderate_DR_697.png
#   inflating: content/-DRD/train_images/Severe DR_74.png
#   inflating: content/-DRD/train_images/Severe DR_34.png
#   inflating: content/-DRD/train_images/c80f79579fed.png
#   inflating: content/-DRD/train_images/03747397839f.png
#   inflating: content/-DRD/train_images/40c24aded50c.png
#   inflating: content/-DRD/train_images/Mild_DR_269.png
#   inflating: content/-DRD/train_images/ccd6dcb2f568.png
#   inflating: content/-DRD/train_images/c8d2d32f7f29.png
#   inflating: content/-DRD/train_images/52ae917fcea4.png
#   inflating: content/-DRD/train_images/4ee1ad981a6d.png
#   inflating: content/-DRD/train_images/Proliferate DR_160.png
#   inflating: content/-DRD/train_images/27e4c800a449.png
#   inflating: content/-DRD/train_images/44e0d56e9d42.png
#   inflating: content/-DRD/train_images/3c726de3ee90.png
#   inflating: content/-DRD/train_images/Mild_DR_189.png
#   inflating: content/-DRD/train_images/0024cdab0c1e.png
#   inflating: content/-DRD/train_images/Mild_DR_24.png
#   inflating: content/-DRD/train_images/Healthy_535.png
#   inflating: content/-DRD/train_images/Healthy_27.png
#   inflating: content/-DRD/train_images/a81b06f50612.png
#   inflating: content/-DRD/train_images/90c982cc2d96.png
#   inflating: content/-DRD/train_images/e13412678eff.png
#   inflating: content/-DRD/train_images/6d7d26025122.png
#   inflating: content/-DRD/train_images/Severe DR_148.png
#   inflating: content/-DRD/train_images/Moderate_DR_14.png
#   inflating: content/-DRD/train_images/Healthy_408.png
#   inflating: content/-DRD/train_images/Moderate_DR_867.png
#   inflating: content/-DRD/train_images/Moderate_DR_313.png
#   inflating: content/-DRD/train_images/Proliferate DR_285.png
#   inflating: content/-DRD/train_images/Proliferate DR_141.png
#   inflating: content/-DRD/train_images/Moderate_DR_665.png
#   inflating: content/-DRD/train_images/4c53cc97ea13.png
#   inflating: content/-DRD/train_images/7350c50667c5.png
#   inflating: content/-DRD/train_images/8bed09514c3b.png
#   inflating: content/-DRD/train_images/Moderate_DR_537.png
#   inflating: content/-DRD/train_images/b96b518596b3.png
#   inflating: content/-DRD/train_images/Severe DR_120.png
#   inflating: content/-DRD/train_images/be6cbf6e5b10.png
#   inflating: content/-DRD/train_images/e4b0df29b96f.png
#   inflating: content/-DRD/train_images/ca9c912ebad7.png
#   inflating: content/-DRD/train_images/Moderate_DR_699.png
#   inflating: content/-DRD/train_images/1f15ca672675.png
#   inflating: content/-DRD/train_images/788ddb0b70b7.png
#   inflating: content/-DRD/train_images/Healthy_457.png
#   inflating: content/-DRD/train_images/Healthy_111.png
#   inflating: content/-DRD/train_images/25dc1b41ed9c.png
#   inflating: content/-DRD/train_images/Moderate_DR_656.png
#   inflating: content/-DRD/train_images/Healthy_423.png
#   inflating: content/-DRD/train_images/Healthy_54.png
#   inflating: content/-DRD/train_images/Mild_DR_314.png
#   inflating: content/-DRD/train_images/Moderate_DR_337.png
#   inflating: content/-DRD/train_images/Proliferate DR_5.png
#   inflating: content/-DRD/train_images/f00ce9b9d6f4.png
#   inflating: content/-DRD/train_images/0773a1c326ad.png
#   inflating: content/-DRD/train_images/aeccef0bdc26.png
#   inflating: content/-DRD/train_images/3486f7096276.png
#   inflating: content/-DRD/train_images/Healthy_146.png
#   inflating: content/-DRD/train_images/Proliferate DR_116.png
#   inflating: content/-DRD/train_images/Healthy_59.png
#   inflating: content/-DRD/train_images/Healthy_235.png
#   inflating: content/-DRD/train_images/3ccf96c1dd6d.png
#   inflating: content/-DRD/train_images/0daddc45d832.png
#   inflating: content/-DRD/train_images/7b49041cbf17.png
#   inflating: content/-DRD/train_images/3f47f83217b5.png
#   inflating: content/-DRD/train_images/Moderate_DR_257.png
#   inflating: content/-DRD/train_images/Healthy_195.png
#   inflating: content/-DRD/train_images/Healthy_872.png
#   inflating: content/-DRD/train_images/Mild_DR_32.png
#   inflating: content/-DRD/train_images/5e7db41b3bee.png
#   inflating: content/-DRD/train_images/Moderate_DR_868.png
#   inflating: content/-DRD/train_images/Moderate_DR_682.png
#   inflating: content/-DRD/train_images/Proliferate DR_3.png
#   inflating: content/-DRD/train_images/Healthy_718.png
#   inflating: content/-DRD/train_images/fa59221cf464.png
#   inflating: content/-DRD/train_images/302bcdb635ff.png
#   inflating: content/-DRD/train_images/Healthy_226.png
#   inflating: content/-DRD/train_images/Mild_DR_183.png
#   inflating: content/-DRD/train_images/Mild_DR_367.png
#   inflating: content/-DRD/train_images/f4ea2a2cfbb9.png
#   inflating: content/-DRD/train_images/Moderate_DR_668.png
#   inflating: content/-DRD/train_images/Moderate_DR_886.png
#   inflating: content/-DRD/train_images/Severe DR_128.png
#   inflating: content/-DRD/train_images/Moderate_DR_348.png
#   inflating: content/-DRD/train_images/Healthy_566.png
#   inflating: content/-DRD/train_images/58b866484a05.png
#   inflating: content/-DRD/train_images/Proliferate DR_24.png
#   inflating: content/-DRD/train_images/Moderate_DR_893.png
#   inflating: content/-DRD/train_images/Healthy_358.png
#   inflating: content/-DRD/train_images/1f31701dd61b.png
#   inflating: content/-DRD/train_images/9870ce41cac4.png
#   inflating: content/-DRD/train_images/df3adfd6ba36.png
#   inflating: content/-DRD/train_images/df5ce3ea7820.png
#   inflating: content/-DRD/train_images/Proliferate DR_228.png
#   inflating: content/-DRD/train_images/Proliferate DR_273.png
#   inflating: content/-DRD/train_images/711d1480d2e3.png
#   inflating: content/-DRD/train_images/Healthy_92.png
#   inflating: content/-DRD/train_images/a8dea22ef903.png
#   inflating: content/-DRD/train_images/Moderate_DR_451.png
#   inflating: content/-DRD/train_images/5eb311bcb5f9.png
#   inflating: content/-DRD/train_images/Healthy_774.png
#   inflating: content/-DRD/train_images/064af6592ba6.png
#   inflating: content/-DRD/train_images/Severe DR_11.png
#   inflating: content/-DRD/train_images/55fd453001cc.png
#   inflating: content/-DRD/train_images/Moderate_DR_659.png
#   inflating: content/-DRD/train_images/Moderate_DR_856.png
#   inflating: content/-DRD/train_images/Mild_DR_149.png
#   inflating: content/-DRD/train_images/Moderate_DR_565.png
#   inflating: content/-DRD/train_images/Moderate_DR_453.png
#   inflating: content/-DRD/train_images/f252046c0fe6.png
#   inflating: content/-DRD/train_images/07419eddd6be.png
#   inflating: content/-DRD/train_images/c3a82acb7d7a.png
#   inflating: content/-DRD/train_images/Healthy_360.png
#   inflating: content/-DRD/train_images/8ac0c44bbf24.png
#   inflating: content/-DRD/train_images/58529a8638d0.png
#   inflating: content/-DRD/train_images/f0e1201b5c1f.png
#   inflating: content/-DRD/train_images/Mild_DR_260.png
#   inflating: content/-DRD/train_images/Moderate_DR_774.png
#   inflating: content/-DRD/train_images/Proliferate DR_100.png
#   inflating: content/-DRD/train_images/Proliferate DR_10.png
#    creating: content/-DRD/test_images/
#   inflating: content/-DRD/test_images/086727c22b75.png
#   inflating: content/-DRD/test_images/3a1bdff4e304.png
#   inflating: content/-DRD/test_images/29cb3c00c82e.png
#   inflating: content/-DRD/test_images/d995728f0e26.png
#   inflating: content/-DRD/test_images/8d955a3d9286.png
#   inflating: content/-DRD/test_images/496039c25f39.png
#   inflating: content/-DRD/test_images/95753b394d4c.png
#   inflating: content/-DRD/test_images/ec727873cdb7.png
#   inflating: content/-DRD/test_images/f32bdf2a84ec.png
#   inflating: content/-DRD/test_images/e976cf76fe42.png
#   inflating: content/-DRD/test_images/d1e17c1f626f.png
#   inflating: content/-DRD/test_images/53959e0a750b.png
#   inflating: content/-DRD/test_images/12411c037cfb.png
#   inflating: content/-DRD/test_images/bf441174ad79.png
#   inflating: content/-DRD/test_images/71eba9a97184.png
#   inflating: content/-DRD/test_images/652a1edabdb7.png
#   inflating: content/-DRD/test_images/e2d902dccbac.png
#   inflating: content/-DRD/test_images/22de26199c44.png
#   inflating: content/-DRD/test_images/7ba4225b323e.png
#   inflating: content/-DRD/test_images/69b3f1028e99.png
#   inflating: content/-DRD/test_images/2bb39124c823.png
#   inflating: content/-DRD/test_images/362ee624995d.png
#   inflating: content/-DRD/test_images/a77c37529ee7.png
#   inflating: content/-DRD/test_images/1620fa014ccb.png
#   inflating: content/-DRD/test_images/25eb93e69a3e.png
#   inflating: content/-DRD/test_images/6dce3f20de26.png
#   inflating: content/-DRD/test_images/fa7a97f4de76.png
#   inflating: content/-DRD/test_images/8c45490f701a.png
#   inflating: content/-DRD/test_images/2cb697cbcb0b.png
#   inflating: content/-DRD/test_images/5b04aa895c31.png
#   inflating: content/-DRD/test_images/04a0773c71fb.png
#   inflating: content/-DRD/test_images/a2d894364873.png
#   inflating: content/-DRD/test_images/59e7f9e69044.png
#   inflating: content/-DRD/test_images/73a0917d732b.png
#   inflating: content/-DRD/test_images/bfd3dcc96967.png
#   inflating: content/-DRD/test_images/132e1876157b.png
#   inflating: content/-DRD/test_images/11f10a8be429.png
#   inflating: content/-DRD/test_images/1e04a80f12dd.png
#   inflating: content/-DRD/test_images/2c754e336552.png
#   inflating: content/-DRD/test_images/228769e96741.png
#   inflating: content/-DRD/test_images/7a5b1c716560.png
#   inflating: content/-DRD/test_images/d465bf00f65f.png
#   inflating: content/-DRD/test_images/4947431500d5.png
#   inflating: content/-DRD/test_images/0946ae407745.png
#   inflating: content/-DRD/test_images/1c6e15aeb154.png
#   inflating: content/-DRD/test_images/d166f5253f48.png
#   inflating: content/-DRD/test_images/887b4413f87c.png
#   inflating: content/-DRD/test_images/a49b59299236.png
#   inflating: content/-DRD/test_images/755615db51d3.png
#   inflating: content/-DRD/test_images/14ab77198610.png
#   inflating: content/-DRD/test_images/9b9907171049.png
#   inflating: content/-DRD/test_images/130887394f97.png
#   inflating: content/-DRD/test_images/a18e97c55688.png
#   inflating: content/-DRD/test_images/810b9603c241.png
#   inflating: content/-DRD/test_images/92eb43fbfd8b.png
#   inflating: content/-DRD/test_images/33cd1f67204e.png
#   inflating: content/-DRD/test_images/600b2b469a2f.png
#   inflating: content/-DRD/test_images/c8beb20d5a63.png
#   inflating: content/-DRD/test_images/e26bf4a0165f.png
#   inflating: content/-DRD/test_images/17b08e34f0ed.png
#   inflating: content/-DRD/test_images/b1f69a5b75d4.png
#   inflating: content/-DRD/test_images/59738e82c527.png
#   inflating: content/-DRD/test_images/9285ad837947.png
#   inflating: content/-DRD/test_images/13065b0ff1e0.png
#   inflating: content/-DRD/test_images/ee98121d0c5a.png
#   inflating: content/-DRD/test_images/b3db392f5ee8.png
#   inflating: content/-DRD/test_images/57cbd5909e16.png
#   inflating: content/-DRD/test_images/e319bce1d9ad.png
#   inflating: content/-DRD/test_images/219828b94b41.png
#   inflating: content/-DRD/test_images/31a6e9b91de3.png
#   inflating: content/-DRD/test_images/93c1af8b625c.png
#   inflating: content/-DRD/test_images/e4c643b8c321.png
#   inflating: content/-DRD/test_images/29ca7f9cb14a.png
#   inflating: content/-DRD/test_images/11dc8d4a66a7.png
#   inflating: content/-DRD/test_images/4d00167f2d05.png
#   inflating: content/-DRD/test_images/ce6af5e7dd4b.png
#   inflating: content/-DRD/test_images/49a91567632e.png
#   inflating: content/-DRD/test_images/657b8609f26f.png
#   inflating: content/-DRD/test_images/64a507309332.png
#   inflating: content/-DRD/test_images/ae3ab8ac036c.png
#   inflating: content/-DRD/test_images/589747aab826.png
#   inflating: content/-DRD/test_images/741ef20e5e28.png
#   inflating: content/-DRD/test_images/cc95391f2576.png
#   inflating: content/-DRD/test_images/31d79157e7c4.png
#   inflating: content/-DRD/test_images/437fa52cb1cb.png
#   inflating: content/-DRD/test_images/43e0368e857b.png
#   inflating: content/-DRD/test_images/6eb52b81fa50.png
#   inflating: content/-DRD/test_images/570982b0dbf2.png
#   inflating: content/-DRD/test_images/e48caeb90d74.png
#   inflating: content/-DRD/test_images/2fb539602f57.png
#   inflating: content/-DRD/test_images/c38bfcb69bac.png
#   inflating: content/-DRD/test_images/6c96703bc565.png
#   inflating: content/-DRD/test_images/cb004a78aecf.png
#   inflating: content/-DRD/test_images/3d83eba14bd2.png
#   inflating: content/-DRD/test_images/052e00f47cfa.png
#   inflating: content/-DRD/test_images/938a59f04582.png
#   inflating: content/-DRD/test_images/006efc72b638.png
#   inflating: content/-DRD/test_images/cbde1c64f27e.png
#   inflating: content/-DRD/test_images/d13d82ddc158.png
#   inflating: content/-DRD/test_images/32bb537f9dec.png
#   inflating: content/-DRD/test_images/c2ab32a760b6.png
#   inflating: content/-DRD/test_images/b7d617607c6e.png
#   inflating: content/-DRD/test_images/551f1e4e2763.png
#   inflating: content/-DRD/test_images/a9bc8e153c30.png
#   inflating: content/-DRD/test_images/c54f83a2d026.png
#   inflating: content/-DRD/test_images/c39d7fde814c.png
#   inflating: content/-DRD/test_images/5f158adf5bbc.png
#   inflating: content/-DRD/test_images/464ee4a542b0.png
#   inflating: content/-DRD/test_images/4fdd1ca8bd89.png
#   inflating: content/-DRD/test_images/8b840ed255d8.png
#   inflating: content/-DRD/test_images/b5ef4a1296d4.png
#   inflating: content/-DRD/test_images/0b88274d5d7d.png
#   inflating: content/-DRD/test_images/f3bebccd8f01.png
#   inflating: content/-DRD/test_images/4db635ee7440.png
#   inflating: content/-DRD/test_images/3da4e0e38f17.png
#   inflating: content/-DRD/test_images/0ad36156ad5d.png
#   inflating: content/-DRD/test_images/448c1f328542.png
#   inflating: content/-DRD/test_images/5325b1c22c61.png
#   inflating: content/-DRD/test_images/8a1791bd2bb0.png
#   inflating: content/-DRD/test_images/8efd5ed7c4d8.png
#   inflating: content/-DRD/test_images/dde91361002c.png
#   inflating: content/-DRD/test_images/edca22bdbeeb.png
#   inflating: content/-DRD/test_images/b3aaa2cd3308.png
#   inflating: content/-DRD/test_images/ef10428bec8e.png
#   inflating: content/-DRD/test_images/3a5d6cc796f1.png
#   inflating: content/-DRD/test_images/76c854fde95e.png
#   inflating: content/-DRD/test_images/6ed9e38a4239.png
#   inflating: content/-DRD/test_images/2c2b9c974ca7.png
#   inflating: content/-DRD/test_images/8eec629c3c8b.png
#   inflating: content/-DRD/test_images/587e6a83a90f.png
#   inflating: content/-DRD/test_images/3832a69f943a.png
#   inflating: content/-DRD/test_images/764b9b51cd9f.png
#   inflating: content/-DRD/test_images/be99a17d1158.png
#   inflating: content/-DRD/test_images/515877da2def.png
#   inflating: content/-DRD/test_images/462507c543fb.png
#   inflating: content/-DRD/test_images/7fe2cff51752.png
#   inflating: content/-DRD/test_images/0299d97f31f7.png
#   inflating: content/-DRD/test_images/0268f4382c67.png
#   inflating: content/-DRD/test_images/5d62c37386fc.png
#   inflating: content/-DRD/test_images/d99a7151297d.png
#   inflating: content/-DRD/test_images/61ff3873c036.png
#   inflating: content/-DRD/test_images/6ae0afd18f89.png
#   inflating: content/-DRD/test_images/5595883f47f0.png
#   inflating: content/-DRD/test_images/e0bb4081ebec.png
#   inflating: content/-DRD/test_images/7ac156fd3932.png
#   inflating: content/-DRD/test_images/d8f6c660bf2d.png
#   inflating: content/-DRD/test_images/e8c65c471b92.png
#   inflating: content/-DRD/test_images/291069435ace.png
#   inflating: content/-DRD/test_images/c829f6b37ac3.png
#   inflating: content/-DRD/test_images/39ff5807f582.png
#   inflating: content/-DRD/test_images/a00e9f3e46b3.png
#   inflating: content/-DRD/test_images/2e4c87ecc92c.png
#   inflating: content/-DRD/test_images/a2319c2af727.png
#   inflating: content/-DRD/test_images/7754a10b07ae.png
#   inflating: content/-DRD/test_images/3a70c2d49381.png
#   inflating: content/-DRD/test_images/6e48f854f7e6.png
#   inflating: content/-DRD/test_images/933724df128e.png
#   inflating: content/-DRD/test_images/cf98137e0faa.png
#   inflating: content/-DRD/test_images/2ec041fd9a0c.png
#   inflating: content/-DRD/test_images/349ab243e75c.png
#   inflating: content/-DRD/test_images/aad278dd0f28.png
#   inflating: content/-DRD/test_images/6ef23497ea54.png
#   inflating: content/-DRD/test_images/f6a79dbb4339.png
#   inflating: content/-DRD/test_images/6853d1c8546d.png
#   inflating: content/-DRD/test_images/667ec71b5003.png
#   inflating: content/-DRD/test_images/8dc530ad4a1e.png
#   inflating: content/-DRD/test_images/263dde841c5e.png
#   inflating: content/-DRD/test_images/c320df3fe094.png
#   inflating: content/-DRD/test_images/b93f6b61c889.png
#   inflating: content/-DRD/test_images/f576e224de55.png
#   inflating: content/-DRD/test_images/8bdd3a1895c8.png
#   inflating: content/-DRD/test_images/8d892f6b5976.png
#   inflating: content/-DRD/test_images/6ea2fc471536.png
#   inflating: content/-DRD/test_images/236c9c9c40c5.png
#   inflating: content/-DRD/test_images/c582e76be4a6.png
#   inflating: content/-DRD/test_images/06cdd3f3f262.png
#   inflating: content/-DRD/test_images/bf599a93ca9b.png
#   inflating: content/-DRD/test_images/d8468d108c02.png
#   inflating: content/-DRD/test_images/b501a5bdd0cc.png
#   inflating: content/-DRD/test_images/e4e847470e49.png
#   inflating: content/-DRD/test_images/98b46d9f4731.png
#   inflating: content/-DRD/test_images/f45ceb654c4d.png
#   inflating: content/-DRD/test_images/009c019a7309.png
#   inflating: content/-DRD/test_images/5edf6828c280.png
#   inflating: content/-DRD/test_images/471ff7e04b2f.png
#   inflating: content/-DRD/test_images/f99a9ad63dda.png
#   inflating: content/-DRD/test_images/8c0f725874af.png
#   inflating: content/-DRD/test_images/0928150bb29a.png
#   inflating: content/-DRD/test_images/43c7740f646a.png
#   inflating: content/-DRD/test_images/8c9cf6f116be.png
#   inflating: content/-DRD/test_images/898232c36d81.png
#   inflating: content/-DRD/test_images/37e7e09c2d93.png
#   inflating: content/-DRD/test_images/b0ac3ccbfb36.png
#   inflating: content/-DRD/test_images/0e428b886e07.png
#   inflating: content/-DRD/test_images/2d6246da3909.png
#   inflating: content/-DRD/test_images/e754bdc1061b.png
#   inflating: content/-DRD/test_images/0c7e66a53ce3.png
#   inflating: content/-DRD/test_images/a252a97fbaec.png
#   inflating: content/-DRD/test_images/8f874a9724df.png
#   inflating: content/-DRD/test_images/3bab6c115f7d.png
#   inflating: content/-DRD/test_images/c689594e1738.png
#   inflating: content/-DRD/test_images/31e9b7060c33.png
#   inflating: content/-DRD/test_images/857e2dafc6d0.png
#   inflating: content/-DRD/test_images/163a8bffdc88.png
#   inflating: content/-DRD/test_images/0aebb1b2aef1.png
#   inflating: content/-DRD/test_images/cc232dbbb4d1.png
#   inflating: content/-DRD/test_images/1d1539c0fb03.png
#   inflating: content/-DRD/test_images/456c55e0d8f9.png
#   inflating: content/-DRD/test_images/e177610cf7a1.png
#   inflating: content/-DRD/test_images/411ee15ad4cf.png
#   inflating: content/-DRD/test_images/af1d9213ef42.png
#   inflating: content/-DRD/test_images/59abc465e159.png
#   inflating: content/-DRD/test_images/5b79366b7eb0.png
#   inflating: content/-DRD/test_images/8b96e506768c.png
#   inflating: content/-DRD/test_images/f07ca35b523b.png
#   inflating: content/-DRD/test_images/34fb98396a24.png
#   inflating: content/-DRD/test_images/51323e9d2070.png
#   inflating: content/-DRD/test_images/c03c647fde23.png
#   inflating: content/-DRD/test_images/f506b2b3c950.png
#   inflating: content/-DRD/test_images/1136833be435.png
#   inflating: content/-DRD/test_images/4d32f2284293.png
#   inflating: content/-DRD/test_images/896c75533897.png
#   inflating: content/-DRD/test_images/6543b4168f98.png
#   inflating: content/-DRD/test_images/a444ca028295.png
#   inflating: content/-DRD/test_images/5416642e06dd.png
#   inflating: content/-DRD/test_images/c97946322879.png
#   inflating: content/-DRD/test_images/acd52452b9a2.png
#   inflating: content/-DRD/test_images/cee9079c5c8c.png
#   inflating: content/-DRD/test_images/1ba29885e4ce.png
#   inflating: content/-DRD/test_images/c8a498c984f3.png
#   inflating: content/-DRD/test_images/bef30368d78d.png
#   inflating: content/-DRD/test_images/427264c3232d.png
#   inflating: content/-DRD/test_images/4686020fa0c6.png
#   inflating: content/-DRD/test_images/7dcbbc17fe47.png
#   inflating: content/-DRD/test_images/ffa73465b705.png
#   inflating: content/-DRD/test_images/ca948114cb53.png
#   inflating: content/-DRD/test_images/c03b523cfb2d.png
#   inflating: content/-DRD/test_images/4b4c0a15473c.png
#   inflating: content/-DRD/test_images/63dd40d7439b.png
#   inflating: content/-DRD/test_images/cb484b214c95.png
#   inflating: content/-DRD/test_images/b6e7ae30e458.png
#   inflating: content/-DRD/test_images/d65a606a9289.png
#   inflating: content/-DRD/test_images/e29765ebf3bc.png
#   inflating: content/-DRD/test_images/1b79278c8cb5.png
#   inflating: content/-DRD/test_images/09b5e952f996.png
#   inflating: content/-DRD/test_images/5598165adbff.png
#   inflating: content/-DRD/test_images/436651e030cb.png
#   inflating: content/-DRD/test_images/88fda3e06e05.png
#   inflating: content/-DRD/test_images/f72a18c76408.png
#   inflating: content/-DRD/test_images/0cad3584e761.png
#   inflating: content/-DRD/test_images/7a4d0a3b5e5a.png
#   inflating: content/-DRD/test_images/be640164686b.png
#   inflating: content/-DRD/test_images/50dab20a4ad4.png
#   inflating: content/-DRD/test_images/b042fdb1e1a1.png
#   inflating: content/-DRD/test_images/ac6c7462887b.png
#   inflating: content/-DRD/test_images/636997a49fcb.png
#   inflating: content/-DRD/test_images/b00235fc4967.png
#   inflating: content/-DRD/test_images/9c73a69a7911.png
#   inflating: content/-DRD/test_images/71047d5e7299.png
#   inflating: content/-DRD/test_images/7d67e38d7ba6.png
#   inflating: content/-DRD/test_images/2e6a99e1df80.png
#   inflating: content/-DRD/test_images/e6834d55bf6b.png
#   inflating: content/-DRD/test_images/03be80919be4.png
#   inflating: content/-DRD/test_images/0b121d798018.png
#   inflating: content/-DRD/test_images/062ed40f5272.png
#   inflating: content/-DRD/test_images/9ff8eaf27f82.png
#   inflating: content/-DRD/test_images/6f8a7b6b30c2.png
#   inflating: content/-DRD/test_images/600afae2d4e9.png
#   inflating: content/-DRD/test_images/0ddb0dbbef76.png
#   inflating: content/-DRD/test_images/4defa0f6e0aa.png
#   inflating: content/-DRD/test_images/51bbd82feec8.png
#   inflating: content/-DRD/test_images/3738406eb0f4.png
#   inflating: content/-DRD/test_images/7015c532679c.png
#   inflating: content/-DRD/test_images/03042a663e54.png
#   inflating: content/-DRD/test_images/8943b2b8c8ea.png
#   inflating: content/-DRD/test_images/3ef3056cc3d0.png
#   inflating: content/-DRD/test_images/8d01494c2821.png
#   inflating: content/-DRD/test_images/41cc795c4acd.png
#   inflating: content/-DRD/test_images/1c241074f213.png
#   inflating: content/-DRD/test_images/d81c3856082a.png
#   inflating: content/-DRD/test_images/9c2c32cbda5a.png
#   inflating: content/-DRD/test_images/51910bcb980d.png
#   inflating: content/-DRD/test_images/a435c6136916.png
#   inflating: content/-DRD/test_images/13e28ec4534a.png
#   inflating: content/-DRD/test_images/ca30526a247c.png
#   inflating: content/-DRD/test_images/d18c404c056f.png
#   inflating: content/-DRD/test_images/c18a0972d652.png
#   inflating: content/-DRD/test_images/49f6ffbc8356.png
#   inflating: content/-DRD/test_images/156350bc41c9.png
#   inflating: content/-DRD/test_images/2f032374b797.png
#   inflating: content/-DRD/test_images/7205b4cbc184.png
#   inflating: content/-DRD/test_images/4d6333d41069.png
#   inflating: content/-DRD/test_images/178bf0bd8902.png
#   inflating: content/-DRD/test_images/ea58b230f540.png
#   inflating: content/-DRD/test_images/d607960647ac.png
#   inflating: content/-DRD/test_images/8e4cf64ec035.png
#   inflating: content/-DRD/test_images/dd525bbb2ca3.png
#    creating: content/-DRD/test_images/.ipynb_checkpoints/
#   inflating: content/-DRD/test_images/c7c003cdaaba.png
#   inflating: content/-DRD/test_images/9baaa9117adb.png
#   inflating: content/-DRD/test_images/c537a3ca84b1.png
#   inflating: content/-DRD/test_images/b4316f572eaa.png
#   inflating: content/-DRD/test_images/73894f64bcb1.png
#   inflating: content/-DRD/test_images/96c21d31212c.png
#   inflating: content/-DRD/test_images/80aa9b30d2f9.png
#   inflating: content/-DRD/test_images/9c27b212d50b.png
#   inflating: content/-DRD/test_images/f3a6c7df5fdc.png
#   inflating: content/-DRD/test_images/616a989990b0.png
#   inflating: content/-DRD/test_images/f7de9615aea3.png
#   inflating: content/-DRD/test_images/35dbd229cfa2.png
#   inflating: content/-DRD/test_images/b5d91947038f.png
#   inflating: content/-DRD/test_images/228e7cf174ae.png
#   inflating: content/-DRD/test_images/9c5ba656e978.png
#   inflating: content/-DRD/test_images/1876ac30fdc5.png
#   inflating: content/-DRD/test_images/c3214eb3f870.png
#   inflating: content/-DRD/test_images/c3fea3498883.png
#   inflating: content/-DRD/test_images/172eb75bc414.png
#   inflating: content/-DRD/test_images/97c4f207ae56.png
#   inflating: content/-DRD/test_images/8adf13f4fc16.png
#   inflating: content/-DRD/test_images/f2320b9e1197.png
#   inflating: content/-DRD/test_images/b5967c4f8545.png
#   inflating: content/-DRD/test_images/57d5d0d42cac.png
#   inflating: content/-DRD/test_images/8142cc87ebb9.png
#   inflating: content/-DRD/test_images/251f4323b63d.png
#   inflating: content/-DRD/test_images/3503d1413125.png
#   inflating: content/-DRD/test_images/f08c01a8a480.png
#   inflating: content/-DRD/test_images/944678405e5e.png
#   inflating: content/-DRD/test_images/607f40adf8b1.png
#   inflating: content/-DRD/test_images/ab6a3748da27.png
#   inflating: content/-DRD/test_images/d60e1e5c5c0f.png
#   inflating: content/-DRD/test_images/2099648072a2.png
#   inflating: content/-DRD/test_images/10205b883f26.png
#   inflating: content/-DRD/test_images/39a7cac6ac9c.png
#   inflating: content/-DRD/test_images/38b53cec399f.png
#   inflating: content/-DRD/test_images/c3e13501e198.png
#   inflating: content/-DRD/test_images/316f294f35ad.png
#   inflating: content/-DRD/test_images/688ae4721ccd.png
#   inflating: content/-DRD/test_images/c475aefa6255.png
#   inflating: content/-DRD/test_images/26978370afb3.png
#   inflating: content/-DRD/test_images/d07a177c50a2.png
#   inflating: content/-DRD/test_images/2ffd44200e6f.png
#   inflating: content/-DRD/test_images/a807402308f2.png
#   inflating: content/-DRD/test_images/aa7e34315323.png
#   inflating: content/-DRD/test_images/bae2e0f0943e.png
#   inflating: content/-DRD/test_images/ae1cc896a422.png
#   inflating: content/-DRD/test_images/14a4f23b07a5.png
#   inflating: content/-DRD/test_images/2da814938e0a.png
#   inflating: content/-DRD/test_images/19f165a25974.png
#   inflating: content/-DRD/test_images/3099f71a8760.png
#   inflating: content/-DRD/test_images/b436e2bfeabe.png
#   inflating: content/-DRD/test_images/6c3053baeb67.png
#   inflating: content/-DRD/test_images/91b81018ff9d.png
#   inflating: content/-DRD/test_images/5168ddccea88.png
#   inflating: content/-DRD/test_images/447d8e8f446d.png
#   inflating: content/-DRD/test_images/4ca3eaf3493f.png
#   inflating: content/-DRD/test_images/fbc8b60526f1.png
#   inflating: content/-DRD/test_images/fee5bd042c3b.png
#   inflating: content/-DRD/test_images/0904fcd03369.png
#   inflating: content/-DRD/test_images/9a9091fd7806.png
#   inflating: content/-DRD/test_images/c0b5445db374.png
#   inflating: content/-DRD/test_images/bab03e16c029.png
#   inflating: content/-DRD/test_images/51f0bf8f1544.png
#   inflating: content/-DRD/test_images/213e9ca67626.png
#   inflating: content/-DRD/test_images/64a4926e85b5.png
#   inflating: content/-DRD/test_images/9f2539320e85.png
#   inflating: content/-DRD/test_images/f9e7f614c91d.png
#   inflating: content/-DRD/test_images/ef5f4ffdd75c.png
#   inflating: content/-DRD/test_images/0a2b5e1a0be8.png
#   inflating: content/-DRD/test_images/e4ea1673d8f8.png
#   inflating: content/-DRD/test_images/9003ab48ebb8.png
#   inflating: content/-DRD/test_images/987f80393a5a.png
#   inflating: content/-DRD/test_images/273a341b5144.png
#   inflating: content/-DRD/test_images/de2bfc6ae8dc.png
#   inflating: content/-DRD/test_images/763bfd250520.png
#   inflating: content/-DRD/test_images/cfe6c3a302c4.png
#   inflating: content/-DRD/test_images/c66bf1a7d923.png
#   inflating: content/-DRD/test_images/c75940045da2.png
#   inflating: content/-DRD/test_images/6a27a25f7a0c.png
#   inflating: content/-DRD/test_images/8214256b4e51.png
#   inflating: content/-DRD/test_images/ba2fc27e7f12.png
#   inflating: content/-DRD/test_images/c8e05928ba0f.png
#   inflating: content/-DRD/test_images/7f9c86406c62.png
#   inflating: content/-DRD/test_images/f5ebdedbba98.png
#   inflating: content/-DRD/test_images/3670a39e7026.png
#   inflating: content/-DRD/test_images/774cafde22b5.png
#   inflating: content/-DRD/test_images/d087cc94e803.png
#   inflating: content/-DRD/test_images/3e2ae41e0730.png
#   inflating: content/-DRD/test_images/c697d6496c5a.png
#   inflating: content/-DRD/test_images/41672ba8bcb1.png
#   inflating: content/-DRD/test_images/5092d7fc1392.png
#   inflating: content/-DRD/test_images/f96fecb16957.png
#   inflating: content/-DRD/test_images/0111b949947e.png
#   inflating: content/-DRD/test_images/f8b184ad0701.png
#   inflating: content/-DRD/test_images/69d21c5c7dce.png
#   inflating: content/-DRD/test_images/069037e82135.png
#   inflating: content/-DRD/test_images/a203f9f5c288.png
#   inflating: content/-DRD/test_images/443b96e2e048.png
#   inflating: content/-DRD/test_images/0af080866c24.png
#   inflating: content/-DRD/test_images/f7b5f3581d20.png
#   inflating: content/-DRD/test_images/586eba507c88.png
#   inflating: content/-DRD/test_images/983b3a401c9e.png
#   inflating: content/-DRD/train.csv
#    creating: content/-DRD/.ipynb_checkpoints/
#   inflating: content/-DRD/test.csv

# %%
import pandas as pd #For reading csv files.
import numpy as np
import matplotlib.pyplot as plt #For plotting.

import PIL.Image as Image #For working with image files.

#Importing torch
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset,DataLoader #For working with data.

from torchvision import models,transforms #For pretrained models,image transformations.

# %%
device = torch.device('cuda')

# %%
path = "/content/DRD/"
train_df = pd.read_csv(f"{path}train.csv")
print(f'No.of.training_samples: {len(train_df)}')

test_df = pd.read_csv(f'{path}test.csv')
print(f'No.of.testing_samples: {len(test_df)}')
# Out:
# No.of.training_samples: 600
# No.of.testing_samples: 400

# %%
train_df.diagnosis.hist()
plt.xticks([0,1,2,3,4])
plt.grid(False)
plt.show()

# %%
from sklearn.utils import class_weight #For calculating weights for each class.
class_weights = class_weight.compute_class_weight(class_weight='balanced',classes=np.array([0,1,2,3,4]),y=train_df['diagnosis'].values)
class_weights = torch.tensor(class_weights,dtype=torch.float).to(device)

print(class_weights)
# Out:
# tensor([0.5000, 2.1429, 0.6030, 2.0000, 2.6667], device='cuda:0')

# %%
num = int(np.random.randint(0,len(train_df)-1,(1,))) #Picks a random number.
sample_image = (f'{path}train_images/{train_df["id_code"][num]}.png')#Image file.
sample_image = Image.open(sample_image)
plt.imshow(sample_image)
plt.axis('off')
plt.title(f'Class: {train_df["diagnosis"][num]}') #Class of the random image.
plt.show()

# %%
class dataset(Dataset): # Inherits from the Dataset class.
    '''
    dataset class overloads the __init__, __len__, __getitem__ methods of the Dataset class.

    Attributes :
        df:  DataFrame object for the csv file.
        data_path: Location of the dataset.
        image_transform: Transformations to apply to the image.
        train: A boolean indicating whether it is a training_set or not.
    '''

    def __init__(self,df,data_path,image_transform=None,train=True): # Constructor.
        super(Dataset,self).__init__() #Calls the constructor of the Dataset class.
        self.df = df
        self.data_path = data_path
        self.image_transform = image_transform
        self.train = train

    def __len__(self):
        return len(self.df) #Returns the number of samples in the dataset.

    def __getitem__(self,index):
        image_id = self.df['id_code'][index]
        image = Image.open(f'{self.data_path}/{image_id}.png') #Image.
        if self.image_transform :
            image = self.image_transform(image) #Applies transformation to the image.

        if self.train :
            label = self.df['diagnosis'][index] #Label.
            return image,label #If train == True, return image & label.

        else:
            return image #If train != True, return image.

# %%
image_transform = transforms.Compose([transforms.Resize([512,512]),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))]) #Transformations to apply to the image.
data_set = dataset(train_df,f'{path}train_images',image_transform=image_transform)

train_set,valid_set = torch.utils.data.random_split(data_set,[540,60])

# %%
train_dataloader = DataLoader(train_set,batch_size=32,shuffle=True) #DataLoader for train_set.
valid_dataloader = DataLoader(valid_set,batch_size=32,shuffle=False)

# %%
model = models.resnet34(pretrained=True)


model.fc = nn.Sequential(nn.Linear(512,256),
                         nn.ReLU(inplace=True),
                         nn.Linear(256,128),
                         nn.ReLU(inplace=True),
                         nn.Linear(128,64),
                         nn.ReLU(inplace=True),
                         nn.Linear(64,5),
                    )
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:01<00:00, 64.3MB/s]

# %%
model = model.to(device)

# %%
def train(dataloader,model,loss_fn,optimizer):
    '''
    train function updates the weights of the model based on the
    loss using the optimizer in order to get a lower loss.

    Args :
         dataloader: Iterator for the batches in the data_set.
         model: Given an input produces an output by multiplying the input with the model weights.
         loss_fn: Calculates the discrepancy between the label & the model's predictions.
         optimizer: Updates the model weights.

    Returns :
         Average loss per batch which is calculated by dividing the losses for all the batches
         with the number of batches.
    '''

    model.train() #Sets the model for training.

    total = 0
    correct = 0
    running_loss = 0

    for batch,(x,y) in enumerate(dataloader): #Iterates through the batches.

        output = model(x.to(device)) #model's predictions.
        loss   = loss_fn(output,y.to(device)) #loss calculation.

        running_loss += loss.item()

        total        += y.size(0)
        predictions   = output.argmax(dim=1).cpu().detach() #Index for the highest score for all the samples in the batch.
        correct      += (predictions == y.cpu().detach()).sum().item() #No.of.cases where model's predictions are equal to the label.

        optimizer.zero_grad() #Gradient values are set to zero.
        loss.backward() #Calculates the gradients.
        optimizer.step() #Updates the model weights.


    avg_loss = running_loss/len(dataloader) # Average loss for a single batch

    print(f'\nTraining Loss = {avg_loss:.6f}',end='\t')
    print(f'Accuracy on Training set = {100*(correct/total):.6f}% [{correct}/{total}]') #Prints the Accuracy.

    return avg_loss

# %%
def validate(dataloader,model,loss_fn):
    '''
    validate function calculates the average loss per batch and the accuracy of the model's predictions.

    Args :
         dataloader: Iterator for the batches in the data_set.
         model: Given an input produces an output by multiplying the input with the model weights.
         loss_fn: Calculates the discrepancy between the label & the model's predictions.

    Returns :
         Average loss per batch which is calculated by dividing the losses for all the batches
         with the number of batches.
    '''

    model.eval() #Sets the model for evaluation.

    total = 0
    correct = 0
    running_loss = 0

    with torch.no_grad():

        for x,y in dataloader:

            output        = model(x.to(device)) #model's output.
            loss          = loss_fn(output,y.to(device)).item() #loss calculation.
            running_loss += loss

            total        += y.size(0)
            predictions   = output.argmax(dim=1).cpu().detach()
            correct      += (predictions == y.cpu().detach()).sum().item()

    avg_loss = running_loss/len(dataloader) #Average loss per batch.

    print(f'\nValidation Loss = {avg_loss:.6f}',end='\t')
    print(f'Accuracy on Validation set = {100*(correct/total):.6f}% [{correct}/{total}]') #Prints the Accuracy.

    return avg_loss

# %%
def optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs):
    '''
    optimize function calls the train & validate functions for (nb_epochs) times.

    Args :
        train_dataloader: DataLoader for the train_set.
        valid_dataloader: DataLoader for the valid_set.
        model: Given an input produces an output by multiplying the input with the model weights.
        loss_fn: Calculates the discrepancy between the label & the model's predictions.
        optimizer: Updates the model weights.
        nb_epochs: Number of epochs.

    Returns :
        Tuple of lists containing losses for all the epochs.
    '''
    #Lists to store losses for all the epochs.
    train_losses = []
    valid_losses = []

    for epoch in range(nb_epochs):
        print(f'\nEpoch {epoch+1}/{nb_epochs}')
        print('-------------------------------')
        train_loss = train(train_dataloader,model,loss_fn,optimizer) #Calls the train function.
        train_losses.append(train_loss)
        valid_loss = validate(valid_dataloader,model,loss_fn) #Calls the validate function.
        valid_losses.append(valid_loss)

    print('\nTraining has completed!')

    return train_losses,valid_losses

# %%
loss_fn   = nn.CrossEntropyLoss(weight=class_weights) #CrossEntropyLoss with class_weights.
optimizer = torch.optim.SGD(model.parameters(),lr=0.001)
nb_epochs = 60
#Call the optimize function.
train_losses, valid_losses = optimize(train_dataloader,valid_dataloader,model,loss_fn,optimizer,nb_epochs)
# Out:
# Epoch 1/60
# -------------------------------
#
# Training Loss = 1.614490	Accuracy on Training set = 31.481481% [170/540]
#
# Validation Loss = 1.610836	Accuracy on Validation set = 35.000000% [21/60]
#
# Epoch 2/60
# -------------------------------
#
# Training Loss = 1.614265	Accuracy on Training set = 31.851852% [172/540]
#
# Validation Loss = 1.609237	Accuracy on Validation set = 35.000000% [21/60]
#
# Epoch 3/60
# -------------------------------
#
# Training Loss = 1.613992	Accuracy on Training set = 31.666667% [171/540]
#
# Validation Loss = 1.608055	Accuracy on Validation set = 38.333333% [23/60]
#
# Epoch 4/60
# -------------------------------
#
# Training Loss = 1.612862	Accuracy on Training set = 31.296296% [169/540]
#
# Validation Loss = 1.607199	Accuracy on Validation set = 38.333333% [23/60]
#
# Epoch 5/60
# -------------------------------
#
# Training Loss = 1.612123	Accuracy on Training set = 31.296296% [169/540]
#
# Validation Loss = 1.606555	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 6/60
# -------------------------------
#
# Training Loss = 1.611136	Accuracy on Training set = 30.740741% [166/540]
#
# Validation Loss = 1.606097	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 7/60
# -------------------------------
#
# Training Loss = 1.611470	Accuracy on Training set = 30.740741% [166/540]
#
# Validation Loss = 1.605832	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 8/60
# -------------------------------
#
# Training Loss = 1.610452	Accuracy on Training set = 30.740741% [166/540]
#
# Validation Loss = 1.605356	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 9/60
# -------------------------------
#
# Training Loss = 1.610089	Accuracy on Training set = 31.481481% [170/540]
#
# Validation Loss = 1.604765	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 10/60
# -------------------------------
#
# Training Loss = 1.610076	Accuracy on Training set = 30.925926% [167/540]
#
# Validation Loss = 1.604458	Accuracy on Validation set = 36.666667% [22/60]
#
# Epoch 11/60
# -------------------------------
#
# Training Loss = 1.609010	Accuracy on Training set = 31.111111% [168/540]
#
# Validation Loss = 1.603761	Accuracy on Validation set = 35.000000% [21/60]
#
# Epoch 12/60
# -------------------------------
#
# Training Loss = 1.609061	Accuracy on Training set = 30.925926% [167/540]
#
# Validation Loss = 1.603829	Accuracy on Validation set = 33.333333% [20/60]
#
# Epoch 13/60
# -------------------------------
#
# Training Loss = 1.607635	Accuracy on Training set = 31.111111% [168/540]
#
# Validation Loss = 1.603116	Accuracy on Validation set = 31.666667% [19/60]
#
# Epoch 14/60
# -------------------------------
#
# Training Loss = 1.607247	Accuracy on Training set = 31.111111% [168/540]
#
# Validation Loss = 1.602861	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 15/60
# -------------------------------
#
# Training Loss = 1.607211	Accuracy on Training set = 30.370370% [164/540]
#
# Validation Loss = 1.602312	Accuracy on Validation set = 30.000000% [18/60]
#
# Epoch 16/60
# -------------------------------
#
# Training Loss = 1.606405	Accuracy on Training set = 30.925926% [167/540]
#
# Validation Loss = 1.601846	Accuracy on Validation set = 30.000000% [18/60]
#
# Epoch 17/60
# -------------------------------
#
# Training Loss = 1.605972	Accuracy on Training set = 30.925926% [167/540]
#
# Validation Loss = 1.601542	Accuracy on Validation set = 30.000000% [18/60]
#
# Epoch 18/60
# -------------------------------
#
# Training Loss = 1.605634	Accuracy on Training set = 30.370370% [164/540]
#
# Validation Loss = 1.601231	Accuracy on Validation set = 31.666667% [19/60]
#
# Epoch 19/60
# -------------------------------
#
# Training Loss = 1.604642	Accuracy on Training set = 29.444444% [159/540]
#
# Validation Loss = 1.600818	Accuracy on Validation set = 31.666667% [19/60]
#
# Epoch 20/60
# -------------------------------
#
# Training Loss = 1.604430	Accuracy on Training set = 29.629630% [160/540]
#
# Validation Loss = 1.600324	Accuracy on Validation set = 30.000000% [18/60]
#
# Epoch 21/60
# -------------------------------
#
# Training Loss = 1.604014	Accuracy on Training set = 30.185185% [163/540]
#
# Validation Loss = 1.600027	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 22/60
# -------------------------------
#
# Training Loss = 1.603954	Accuracy on Training set = 30.000000% [162/540]
#
# Validation Loss = 1.599623	Accuracy on Validation set = 31.666667% [19/60]
#
# Epoch 23/60
# -------------------------------
#
# Training Loss = 1.602897	Accuracy on Training set = 29.444444% [159/540]
#
# Validation Loss = 1.599267	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 24/60
# -------------------------------
#
# Training Loss = 1.603331	Accuracy on Training set = 30.740741% [166/540]
#
# Validation Loss = 1.599149	Accuracy on Validation set = 30.000000% [18/60]
#
# Epoch 25/60
# -------------------------------
#
# Training Loss = 1.602006	Accuracy on Training set = 30.185185% [163/540]
#
# Validation Loss = 1.598340	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 26/60
# -------------------------------
#
# Training Loss = 1.601715	Accuracy on Training set = 29.444444% [159/540]
#
# Validation Loss = 1.597899	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 27/60
# -------------------------------
#
# Training Loss = 1.601883	Accuracy on Training set = 28.703704% [155/540]
#
# Validation Loss = 1.597700	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 28/60
# -------------------------------
#
# Training Loss = 1.600967	Accuracy on Training set = 29.814815% [161/540]
#
# Validation Loss = 1.597333	Accuracy on Validation set = 25.000000% [15/60]
#
# Epoch 29/60
# -------------------------------
#
# Training Loss = 1.600766	Accuracy on Training set = 29.444444% [159/540]
#
# Validation Loss = 1.597176	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 30/60
# -------------------------------
#
# Training Loss = 1.600100	Accuracy on Training set = 28.148148% [152/540]
#
# Validation Loss = 1.596499	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 31/60
# -------------------------------
#
# Training Loss = 1.599503	Accuracy on Training set = 28.333333% [153/540]
#
# Validation Loss = 1.595958	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 32/60
# -------------------------------
#
# Training Loss = 1.598302	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.595550	Accuracy on Validation set = 25.000000% [15/60]
#
# Epoch 33/60
# -------------------------------
#
# Training Loss = 1.598855	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.595530	Accuracy on Validation set = 28.333333% [17/60]
#
# Epoch 34/60
# -------------------------------
#
# Training Loss = 1.598025	Accuracy on Training set = 27.407407% [148/540]
#
# Validation Loss = 1.594805	Accuracy on Validation set = 26.666667% [16/60]
#
# Epoch 35/60
# -------------------------------
#
# Training Loss = 1.597492	Accuracy on Training set = 26.851852% [145/540]
#
# Validation Loss = 1.594421	Accuracy on Validation set = 26.666667% [16/60]
#
# Epoch 36/60
# -------------------------------
#
# Training Loss = 1.596746	Accuracy on Training set = 28.888889% [156/540]
#
# Validation Loss = 1.594250	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 37/60
# -------------------------------
#
# Training Loss = 1.596587	Accuracy on Training set = 28.703704% [155/540]
#
# Validation Loss = 1.593784	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 38/60
# -------------------------------
#
# Training Loss = 1.595627	Accuracy on Training set = 29.444444% [159/540]
#
# Validation Loss = 1.593230	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 39/60
# -------------------------------
#
# Training Loss = 1.595069	Accuracy on Training set = 28.888889% [156/540]
#
# Validation Loss = 1.592372	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 40/60
# -------------------------------
#
# Training Loss = 1.594725	Accuracy on Training set = 28.333333% [153/540]
#
# Validation Loss = 1.592287	Accuracy on Validation set = 25.000000% [15/60]
#
# Epoch 41/60
# -------------------------------
#
# Training Loss = 1.594314	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.591814	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 42/60
# -------------------------------
#
# Training Loss = 1.593109	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.591258	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 43/60
# -------------------------------
#
# Training Loss = 1.593071	Accuracy on Training set = 29.259259% [158/540]
#
# Validation Loss = 1.591135	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 44/60
# -------------------------------
#
# Training Loss = 1.592236	Accuracy on Training set = 30.370370% [164/540]
#
# Validation Loss = 1.590548	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 45/60
# -------------------------------
#
# Training Loss = 1.591796	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.589835	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 46/60
# -------------------------------
#
# Training Loss = 1.590711	Accuracy on Training set = 28.518519% [154/540]
#
# Validation Loss = 1.589559	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 47/60
# -------------------------------
#
# Training Loss = 1.590202	Accuracy on Training set = 28.518519% [154/540]
#
# Validation Loss = 1.588582	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 48/60
# -------------------------------
#
# Training Loss = 1.588602	Accuracy on Training set = 29.074074% [157/540]
#
# Validation Loss = 1.588489	Accuracy on Validation set = 20.000000% [12/60]
#
# Epoch 49/60
# -------------------------------
#
# Training Loss = 1.589504	Accuracy on Training set = 28.333333% [153/540]
#
# Validation Loss = 1.587710	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 50/60
# -------------------------------
#
# Training Loss = 1.588087	Accuracy on Training set = 27.592593% [149/540]
#
# Validation Loss = 1.587216	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 51/60
# -------------------------------
#
# Training Loss = 1.587964	Accuracy on Training set = 28.888889% [156/540]
#
# Validation Loss = 1.586658	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 52/60
# -------------------------------
#
# Training Loss = 1.587052	Accuracy on Training set = 27.777778% [150/540]
#
# Validation Loss = 1.586325	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 53/60
# -------------------------------
#
# Training Loss = 1.586642	Accuracy on Training set = 25.555556% [138/540]
#
# Validation Loss = 1.586128	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 54/60
# -------------------------------
#
# Training Loss = 1.585733	Accuracy on Training set = 29.629630% [160/540]
#
# Validation Loss = 1.585153	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 55/60
# -------------------------------
#
# Training Loss = 1.584461	Accuracy on Training set = 28.703704% [155/540]
#
# Validation Loss = 1.584324	Accuracy on Validation set = 20.000000% [12/60]
#
# Epoch 56/60
# -------------------------------
#
# Training Loss = 1.584968	Accuracy on Training set = 28.518519% [154/540]
#
# Validation Loss = 1.584145	Accuracy on Validation set = 20.000000% [12/60]
#
# Epoch 57/60
# -------------------------------
#
# Training Loss = 1.583236	Accuracy on Training set = 28.703704% [155/540]
#
# Validation Loss = 1.583097	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 58/60
# -------------------------------
#
# Training Loss = 1.582399	Accuracy on Training set = 28.703704% [155/540]
#
# Validation Loss = 1.582547	Accuracy on Validation set = 21.666667% [13/60]
#
# Epoch 59/60
# -------------------------------
#
# Training Loss = 1.582897	Accuracy on Training set = 27.962963% [151/540]
#
# Validation Loss = 1.582154	Accuracy on Validation set = 23.333333% [14/60]
#
# Epoch 60/60
# -------------------------------
#
# Training Loss = 1.583265	Accuracy on Training set = 27.222222% [147/540]
#
# Validation Loss = 1.581316	Accuracy on Validation set = 23.333333% [14/60]
#
# Training has completed!

# %%
epochs = range(nb_epochs)
plt.plot(epochs, train_losses, 'g', label='Training loss')
plt.plot(epochs, valid_losses, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
torch.save(model,'DR-2.pth')

# %%
test_set = dataset(test_df,f'{path}test_images',image_transform = image_transform,train = False )

test_dataloader = DataLoader(test_set, batch_size=32, shuffle=False)

# %%
def test(dataloader,model):
    '''
    test function predicts the labels given an image batches.

    Args :
         dataloader: DataLoader for the test_set.
         model: Given an input produces an output by multiplying the input with the model weights.

    Returns :
         List of predicted labels.
    '''

    model.eval() #Sets the model for evaluation.

    labels = [] #List to store the predicted labels.

    with torch.no_grad():

        for batch,x in enumerate(dataloader):

            output = model(x.to(device))

            predictions = output.argmax(dim=1).cpu().detach().tolist() #Predicted labels for an image batch.
            labels.extend(predictions)

    print('Testing has completed')

    return labels

# %%
labels = test(test_dataloader,model)
# Out:
# Testing has completed
